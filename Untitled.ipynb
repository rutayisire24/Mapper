# %%
import streamlit as st
import streamlit_folium as st_folium
import folium
import pandas as pd
import geopandas as gpd
import os
import matplotlib.pyplot as plt

# %%
geojson_path = 'Geojson/District.geojson'

# %%
gdf = gpd.read_file(geojson_path)

# %%
gdf.head()
# Out:
#             id               name  hasCoordinatesDown  hasCoordinatesUp
# 0  NREoMszwQZW      Abim District                True              True  \
# 1  QYiQ2KqgCxj  Adjumani District                True              True
# 2  ztIyIYAzFKp     Agago District                True              True
# 3  p7EEgDEX3jT  Alebtong District                True              True
# 4  ZuQHWOaFQVM  Amolatar District                True              True
#
#    level grandParentParentGraph grandParentId              parentGraph
# 0      3                          akV6429SUqu  akV6429SUqu/jdlbNUwJiKX  \
# 1      3                          akV6429SUqu  akV6429SUqu/BD3XaQ7cQAp
# 2      3                          akV6429SUqu  akV6429SUqu/SUvODYOcaVf
# 3      3                          akV6429SUqu  akV6429SUqu/DWPnYhoqza0
# 4      3                          akV6429SUqu  akV6429SUqu/DWPnYhoqza0
#
#       parentId parentName                              style
# 0  jdlbNUwJiKX   Karamoja  {'color': '#111111', 'weight': 1}  \
# 1  BD3XaQ7cQAp  West Nile  {'color': '#111111', 'weight': 1}
# 2  SUvODYOcaVf     Acholi  {'color': '#111111', 'weight': 1}
# 3  DWPnYhoqza0      Lango  {'color': '#111111', 'weight': 1}
# 4  DWPnYhoqza0      Lango  {'color': '#111111', 'weight': 1}
#
#             labelStyle     type
# 0  {'paddingTop': '0'}  Polygon  \
# 1  {'paddingTop': '0'}  Polygon
# 2  {'paddingTop': '0'}  Polygon
# 3  {'paddingTop': '0'}  Polygon
# 4  {'paddingTop': '0'}  Polygon
#
#                                             geometry
# 0  POLYGON ((33.52330 2.66530, 33.52320 2.66550, ...
# 1  POLYGON ((31.81750 2.95070, 31.81730 2.95080, ...
# 2  POLYGON ((33.52330 2.66530, 33.52330 2.66530, ...
# 3  POLYGON ((33.44290 2.36390, 33.44270 2.36340, ...
# 4  POLYGON ((32.58710 1.65120, 32.59660 1.65510, ...
